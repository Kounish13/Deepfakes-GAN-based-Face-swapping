# %%
#Importing Modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("/content/Iris.csv")

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#Number of null values
no_null=df.isna().sum()
no_null
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df['Species'] = df['Species'].map({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2})

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
df['Species'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: Species, dtype: int64

# %%
X = df.drop(["Id"], axis=1)

# %%
X.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
X = X.sample(frac = 1)

# %%
X.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 129            7.2           3.0            5.8           1.6        2
# 16             5.4           3.9            1.3           0.4        0
# 94             5.6           2.7            4.2           1.3        1
# 26             5.0           3.4            1.6           0.4        0
# 77             6.7           3.0            5.0           1.7        1

# %%
y=X['Species']

# %%
y.value_counts()
# Out:
# 2    50
# 0    50
# 1    50
# Name: Species, dtype: int64

# %%
x=X.drop(["Species"], axis=1)

# %%
x.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 129            7.2           3.0            5.8           1.6
# 16             5.4           3.9            1.3           0.4
# 94             5.6           2.7            4.2           1.3
# 26             5.0           3.4            1.6           0.4
# 77             6.7           3.0            5.0           1.7

# %%
from scipy.sparse import coo_matrix
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE
from sklearn.feature_selection import chi2
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
scaler = StandardScaler()
x=scaler.fit_transform(x)

# %%
XX=pd.DataFrame(x)

# %%
XX.head()
# Out:
#           0         1         2         3
# 0  1.643844 -0.124958  1.160819  0.527645
# 1 -0.537178  1.957669 -1.398138 -1.050031
# 2 -0.294842 -0.819166  0.250967  0.133226
# 3 -1.021849  0.800654 -1.227541 -1.050031
# 4  1.038005 -0.124958  0.705893  0.659118

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x, y, stratify=y, train_size=0.8, random_state=1
)

# %%
from sklearn.metrics import classification_report, confusion_matrix, f1_score, precision_recall_curve, ConfusionMatrixDisplay, accuracy_score
import torch

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
x_train=torch.from_numpy(x_train.astype(np.float32))
x_test=torch.from_numpy(x_test.astype(np.float32))

# %%
y_train=torch.from_numpy(y_train.to_numpy().astype(np.float32))
y_test=torch.from_numpy(y_test.to_numpy().astype(np.float32))

# %%
x_train.shape
# Out:
# torch.Size([120, 4])

# %%
# y_train=y_train.view(y_train.shape[0],1)
# y_test=y_test.view(y_test.shape[0],1)

# %%
y_train = y_train.long()

# %%
class model(torch.nn.Module):
 def __init__(self,no_input_features):
   super(model,self).__init__()
   self.layer1=torch.nn.Linear(no_input_features,20)
   self.relu=torch.nn.ReLU()
   self.layer2=torch.nn.Linear(20,3)
 def forward(self,x):
   y_predicted=self.layer1(x)
   y_predicted=self.relu(y_predicted)
   y_predicted=self.layer2(y_predicted)
   return y_predicted

# %%
n_features = 4
model=model(n_features)

# %%
criterion=torch.nn.CrossEntropyLoss()
optimizer=torch.optim.SGD
# epoch: 510 ,loss= 0.07564632594585419
# epoch: 520 ,loss= 0.07473538815975189
# epoch: 530 ,loss= 0.07386364787817001
# epoch: 540 ,loss= 0.07302936911582947
# epoch: 550 ,loss= 0.07223041355609894
# epoch: 560 ,loss= 0.07146155834197998
# epoch: 570 ,loss= 0.07072499394416809
# epoch: 580 ,loss= 0.0700196921825409
# epoch: 590 ,loss= 0.06934250891208649
# epoch: 600 ,loss= 0.0686926394701004
# epoch: 610 ,loss= 0.06806757301092148
# epoch: 620 ,loss= 0.06746575236320496
# epoch: 630 ,loss= 0.06688571721315384
# epoch: 640 ,loss= 0.06632642447948456
# epoch: 650 ,loss= 0.06578611582517624
# epoch: 660 ,loss= 0.06526382267475128
# epoch: 670 ,loss= 0.06475917994976044
# epoch: 680 ,loss= 0.06427136063575745
# epoch: 690 ,loss= 0.06379947811365128
# epoch: 700 ,loss= 0.06334277242422104
# epoch: 710 ,loss= 0.06290058046579361
# epoch: 720 ,loss= 0.0624721497297287
# epoch: 730 ,loss= 0.062056805938482285
# epoch: 740 ,loss= 0.06165403500199318
# epoch: 750 ,loss= 0.06126319244503975
# epoch: 760 ,loss= 0.060884274542331696
# epoch: 770 ,loss= 0.060516826808452606
# epoch: 780 ,loss= 0.06015227735042572
# epoch: 790 ,loss= 0.059793755412101746
# epoch: 800 ,loss= 0.05944528058171272
# epoch: 810 ,loss= 0.05910623446106911
# epoch: 820 ,loss= 0.05877659469842911
# epoch: 830 ,loss= 0.05845560505986214
# epoch: 840 ,loss= 0.058143433183431625
# epoch: 850 ,loss= 0.05783943831920624
# epoch: 860 ,loss= 0.05754302814602852
# epoch: 870 ,loss= 0.05725390464067459
# epoch: 880 ,loss= 0.056971777230501175
# epoch: 890 ,loss= 0.05669645220041275
# epoch: 900 ,loss= 0.05642763897776604
# epoch: 910 ,loss= 0.056165095418691635
# epoch: 920 ,loss= 0.05590885877609253
# epoch: 930 ,loss= 0.0556584931910038
# epoch: 940 ,loss= 0.055413659662008286
# epoch: 950 ,loss= 0.05517425760626793
# epoch: 960 ,loss= 0.05494014173746109
# epoch: 970 ,loss= 0.05471106246113777
# epoch: 980 ,loss= 0.054487038403749466
# epoch: 990 ,loss= 0.05427570268511772
# epoch: 1000 ,loss= 0.054070573300123215

# %%
with torch.no_grad():
 y_pred=model(x_test)
 y_pred_class=y_pred.round()
 y_pred_class=np.argmax(y_pred_class,axis=1)
 accuracy=(y_pred_class.eq(y_test).sum())/float(y_test.shape[0])
 print(accuracy.item())
# Out:
# 1.0

# %%
print("Accuracy is "+str(accuracy.item()*100)+'%')
# Out:
# Accuracy is 100.0%
